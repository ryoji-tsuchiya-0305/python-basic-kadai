# %%
top_length = 10
botom_length = 20
height = 5

area_trapezoid =( (top_length + botom_length) * height / 2)

print(f"上辺{top_length}㎝、下辺{botom_length}㎝、高さ{height}㎝の台形の面積は{area_trapezoid}㎠")
# Out:
# 上辺10㎝、下辺20㎝、高さ5㎝の台形の面積は75.0㎠
